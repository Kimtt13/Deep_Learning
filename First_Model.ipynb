# %% [markdown]
# # First Neural Network

# %%
# Import required libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load the MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the input data
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Image example
plt.imshow(x_train[9])
plt.show()

# %%
# Define the model architecture
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)), # Flatten the 28x28 input image into a 1D array of 784 values
    tf.keras.layers.Dense(128, activation='relu'), # Dense layer with 128 neurons and ReLU activation
    tf.keras.layers.Dropout(0.2), # Dropout layer for regularization to prevent overfitting
    tf.keras.layers.Dense(10, activation='softmax') # Output layer with 10 neurons (one for each class) and softmax activation
])

# Compile the model
model.compile(optimizer='adam', # Use the Adam optimizer
              loss='sparse_categorical_crossentropy', # Sparse categorical crossentropy loss for multi-class classification
              metrics=['accuracy']) # Track accuracy metric during training

# Train the model on the dataset
history = model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 8s 4ms/step - loss: 0.3139 - accuracy: 0.9093 - val_loss: 0.1296 - val_accuracy: 0.9633
# Epoch 2/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1533 - accuracy: 0.9546 - val_loss: 0.0921 - val_accuracy: 0.9743
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1149 - accuracy: 0.9648 - val_loss: 0.0814 - val_accuracy: 0.9758
# Epoch 4/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0919 - accuracy: 0.9720 - val_loss: 0.0801 - val_accuracy: 0.9763
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0799 - accuracy: 0.9754 - val_loss: 0.0710 - val_accuracy: 0.9802
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0691 - accuracy: 0.9785 - val_loss: 0.0752 - val_accuracy: 0.9790
# Epoch 7/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0612 - accuracy: 0.9807 - val_loss: 0.0728 - val_accuracy: 0.9800
# Epoch 8/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0567 - accuracy: 0.9808 - val_loss: 0.0770 - val_accuracy: 0.9783
# Epoch 9/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0496 - accuracy: 0.9838 - val_loss: 0.0724 - val_accuracy: 0.9805
# Epoch 10/10
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0468 - accuracy: 0.9841 - val_loss: 0.0722 - val_accuracy: 0.9797

# %%
# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(x_test, y_test)

# Print the test loss and accuracy
print(f"Test loss: {test_loss}, Test accuracy: {test_accuracy}")
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0695 - accuracy: 0.9797
# Test loss: 0.06946279853582382, Test accuracy: 0.9797000288963318

# %%
# Visualize the training history
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
